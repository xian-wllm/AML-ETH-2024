# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = './out/submission_wavelets1.csv'
target_column = 'y'

# Lire le fichier CSV
data = pd.read_csv(file_path)

# Vérifier les colonnes
if target_column not in data.columns:
    raise ValueError(f"La colonne '{target_column}' n'existe pas dans le dataset.")

# Compter les occurrences de chaque classe
class_distribution = data[target_column].value_counts()

# Afficher les comptes
print("Distribution des classes :")
print(class_distribution)

# Visualiser la distribution
plt.figure(figsize=(10, 6))
class_distribution.plot(kind='bar')
plt.title('Distribution des classes')
plt.xlabel('Classes')
plt.ylabel('Nombre d\'occurrences')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Distribution des classes :
# y
# 0.0    1862
# 2.0    1073
# 1.0     300
# 3.0     176
# Name: count, dtype: int64

# %%
file_path = "./out/submission_wavelets_wo_upsampling_RF_XGBoost-SVM-GB.csv"
target_column = 'y'

# Lire le fichier CSV
data = pd.read_csv(file_path)

# Vérifier les colonnes
if target_column not in data.columns:
    raise ValueError(f"La colonne '{target_column}' n'existe pas dans le dataset.")

# Compter les occurrences de chaque classe
class_distribution = data[target_column].value_counts()

# Afficher les comptes
print("Distribution des classes :")
print(class_distribution)

# Visualiser la distribution
plt.figure(figsize=(10, 6))
class_distribution.plot(kind='bar')
plt.title('Distribution des classes')
plt.xlabel('Classes')
plt.ylabel('Nombre d\'occurrences')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Distribution des classes :
# y
# 0.0    2156
# 2.0     843
# 1.0     293
# 3.0     119
# Name: count, dtype: int64
